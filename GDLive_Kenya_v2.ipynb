# %% [markdown]
# # GiveDirectly Kenya Project
#
# ![image.png](attachment:image.png)
#
#
# - GiveDirectly is the first — and largest — nonprofit that lets donors send money directly to the world’s poorest.

# %%
# Importing Python packages
import sys
print('Python: {}'.format(sys.version))
# scipy
import scipy
print('scipy: {}'.format(scipy.__version__))
# numpy
import numpy
print('numpy: {}'.format(numpy.__version__))
# matplotlib
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# pandas
import pandas
print('pandas: {}'.format(pandas.__version__))
# scikit-learn
import sklearn
print('sklearn: {}'.format(sklearn.__version__))
# Out:
# Python: 3.7.4 (default, Aug 13 2019, 15:17:50)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# scipy: 1.3.1
# numpy: 1.17.2
# matplotlib: 3.1.1
# pandas: 0.25.1
# sklearn: 0.21.3

# %%
# Loading data from the csv file
from pandas import read_csv

opened_file = open('/Users/tiffany/Downloads/GDLive Kenya free text data - 20200602.csv')
names = ['id', 'project', 'spending_initial', 'spending_repeated_1', 'achievement', 'hardship', 'day', 'daily_life_repeated', 'life_different_future']
GDLive_Kenya_DS2_raw = read_csv(opened_file, names=names)
opened_file.close()

#Dropping the old column headers from the dataset
GDLive_Kenya_DS2_clean = GDLive_Kenya_DS2_raw.drop([0])
GDLive_Kenya_DS2_clean.head(10)



import numpy as np
GDLive_Kenya_DS2_clean.head(10)
# Out:
#              id                project  \
# 1   gd-15468784  high_throughput_kenya
# 2   gd-15768029  high_throughput_kenya
# 3   gd-13778268  high_throughput_kenya
# 4   gd-13737334  high_throughput_kenya
# 5   gd-15594011  high_throughput_kenya
# 6   gd-15076516  high_throughput_kenya
# 7   gd-15347146  high_throughput_kenya
# 8   gd-15128217  high_throughput_kenya
# 9   gd-15130448  high_throughput_kenya
# 10  gd-13933468  high_throughput_kenya
#
#                                      spending_initial  \
# 1   I spent my first transfer on moving to my home...
# 2    I spent my first my house on paying school fe...
# 3                                                 NaN
# 4   I spent my first transfer  on buying  14 bags ...
# 5   I used my first transfer to construct a kitche...
# 6   I spent my first transfer on purchasing large ...
# 7   I used 20 KES to settle my school fee balance....
# 8   I first built a house, am a widow who was stay...
# ...

# %%
import pandas as pd
pd.crosstab(index=GDLive_Kenya_DS2_clean['project'],  # Make a crosstab
                      columns="count")
# Out:
# col_0                  count
# project
# high_throughput_kenya   6967
# standard_kenya         16109

# %%
# Loading data from the csv file
from pandas import read_csv

opened_file = open('/Users/tiffany/Downloads/Tiffany/GDLive Kenya free text data 2.csv')
names = ['id', 'project', 'paymentNumber', 'dailyLife1', 'dailyLife2', 'goals', 'goals2', 'immidiateDiff', 'expectedDiff6m', 'immidiateDiff2']
GDLive_Kenya_DS1_raw = read_csv(opened_file, names=names)
opened_file.close()

#Dropping the old column headers from the dataset
GDLive_Kenya_DS1_clean = GDLive_Kenya_DS1_raw.drop([0])
GDLive_Kenya_DS1_clean.head(10)
# Out:
#              id    project paymentNumber  \
# 1   gd-21311191  ubi_kenya             1
# 2   gd-20998269  ubi_kenya             1
# 3   gd-21195082  ubi_kenya             7
# 4   gd-24619085  ubi_kenya             1
# 5   gd-22293704  ubi_kenya             1
# 6   gd-24855377  ubi_kenya             1
# 7   gd-21782417  ubi_kenya             2
# 8   gd-21185479  ubi_kenya             1
# 9   gd-22464036  ubi_kenya             1
# 10  gd-21009909  ubi_kenya             8
#
#                                            dailyLife1  \
# 1                                                 NaN
# 2   The biggest difference is seeing my son contin...
# 3                                                 NaN
# 4   The biggest difference in my daily life is tha...
# 5   I am able to save because I receive money ever...
# 6   The greatest difference in my life is that now...
# 7   The biggest difference in my daily life is tha...
# 8                                                 NaN
# ...
